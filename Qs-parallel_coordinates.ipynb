# %%
import pandas as pd
data = pd.read_csv('23년 qs4.csv') #여기서부터
data
# Out:
#      rank display rank display2  \
# 0               1             1
# 1               2            3=
# 2               3            3=
# 3               4             2
# 4               5             5
# ...           ...           ...
# 1417        1401+         1201+
# 1418        1401+         1201+
# 1419        1401+         1201+
# 1420        1401+           NaN
# 1421        1401+           NaN
#
#                                            institution location code  \
# 0         Massachusetts Institute of Technology (MIT)             US
# 1                              University of Cambridge            UK
# 2                                  Stanford University            US
# 3                                 University of Oxford            UK
# 4                                   Harvard University            US
# ...                                                ...           ...
# 1417  Universidad Nacional Aut?noma de Honduras (UNAH)            HN
# ...

# %%
data.fillna(0)
# Out:
#      rank display rank display2  \
# 0               1             1
# 1               2            3=
# 2               3            3=
# 3               4             2
# 4               5             5
# ...           ...           ...
# 1417        1401+         1201+
# 1418        1401+         1201+
# 1419        1401+         1201+
# 1420        1401+             0
# 1421        1401+             0
#
#                                            institution location code  \
# 0         Massachusetts Institute of Technology (MIT)             US
# 1                              University of Cambridge            UK
# 2                                  Stanford University            US
# 3                                 University of Oxford            UK
# 4                                   Harvard University            US
# ...                                                ...           ...
# 1417  Universidad Nacional Aut?noma de Honduras (UNAH)            HN
# ...

# %%
name_array = data[['institution']]
n = name_array[name_array.index < 50]
n
# Out:
#                                           institution
# 0        Massachusetts Institute of Technology (MIT)
# 1                             University of Cambridge
# 2                                 Stanford University
# 3                                University of Oxford
# 4                                  Harvard University
# 5        California Institute of Technology (Caltech)
# 6                             Imperial College London
# 7                                                 UCL
# 8   ETH Zurich - Swiss Federal Institute of Techno...
# 9                               University of Chicago
# 10             National University of Singapore (NUS)
# 11                                  Peking University
# 12                         University of Pennsylvania
# 13                                Tsinghua University
# 14                        The University of Edinburgh
# 15                                               EPFL
# ...

# %%
narray_value = n.values
narray_value
# Out:
# array([['Massachusetts Institute of Technology (MIT) '],
#        ['University of Cambridge'],
#        ['Stanford University'],
#        ['University of Oxford'],
#        ['Harvard University'],
#        ['California Institute of Technology (Caltech)'],
#        ['Imperial College London'],
#        ['UCL'],
#        ['ETH Zurich - Swiss Federal Institute of Technology'],
#        ['University of Chicago'],
#        ['National University of Singapore (NUS)'],
#        ['Peking University'],
#        ['University of Pennsylvania'],
#        ['Tsinghua University'],
#        ['The University of Edinburgh'],
#        ['EPFL'],
#        ['Princeton University'],
#        ['Yale University'],
#        ['Nanyang Technological University, Singapore (NTU)'],
#        ['Cornell University'],
#        ['The University of Hong Kong'],
#        ['Columbia University'],
#        ['The University of Tokyo'],
#        ['Johns Hopkins University'],
#        ['University of Michigan-Ann Arbor'],
# ...

# %%
data5 = data[data.index < 50]
data5 = data5.fillna(0)
data5
# Out:
#    rank display rank display2  \
# 0             1             1
# 1             2            3=
# 2             3            3=
# 3             4             2
# 4             5             5
# 5            6=             6
# 6            6=             7
# 7             8            8=
# 8             9            8=
# 9            10            10
# 10           11            11
# 11           12            18
# 12           13            13
# 13           14            17
# 14           15            16
# 15          16=           14=
# 16          16=            20
# 17           18           14=
# 18           19            12
# 19           20            21
# 20           21            22
# 21           22            19
# 22           23           23=
# 23           24            25
# 24           25           23=
# 25           26            44
# 26           27            32
# 27           28           27=
# 28           29            36
# 29           30           27=
# ...

# %%
Qs_1 = data5[['institution', 'ar score', 'er score', 'fsr score',  'cpf score', 'ifr score', 'isr score',
                'irn score', 'ger score', 'score scaled']]
Qs_1
# Out:
#                                           institution  ar score  er score  \
# 0        Massachusetts Institute of Technology (MIT)      100.0     100.0
# 1                             University of Cambridge     100.0     100.0
# 2                                 Stanford University     100.0     100.0
# 3                                University of Oxford     100.0     100.0
# 4                                  Harvard University     100.0     100.0
# 5        California Institute of Technology (Caltech)      96.5      87.1
# 6                             Imperial College London      98.3      99.7
# 7                                                 UCL      99.4      98.6
# 8   ETH Zurich - Swiss Federal Institute of Techno...      98.6      91.3
# 9                               University of Chicago      99.2      92.2
# 10             National University of Singapore (NUS)      99.5      94.1
# 11                                  Peking University      99.3      96.5
# ...

# %%
specify = Qs_1[Qs_1['institution'] == 'Massachusetts Institute of Technology (MIT) ']
specify2 = Qs_1[Qs_1['institution'] == 'University of Cambridge']
specify3 = Qs_1[Qs_1['institution'] == 'Stanford University']
specify4 = Qs_1[Qs_1['institution'] == 'University of Oxford']
specify5 = Qs_1[Qs_1['institution'] == 'Harvard University']
merge1 = pd.concat([specify, specify2, specify3, specify4, specify5])
merge1
# Out:
#                                     institution  ar score  er score  \
# 0  Massachusetts Institute of Technology (MIT)      100.0     100.0
# 1                       University of Cambridge     100.0     100.0
# 2                           Stanford University     100.0     100.0
# 3                          University of Oxford     100.0     100.0
# 4                            Harvard University     100.0     100.0
#
#    fsr score  cpf score  ifr score  isr score  irn score  ger score  \
# 0      100.0      100.0      100.0       90.0       96.1      100.0
# 1      100.0       92.3      100.0       96.3       99.5      100.0
# 2      100.0       99.9       99.8       60.3       96.3      100.0
# 3      100.0       90.0       98.8       98.4       99.9      100.0
# 4       99.4      100.0       76.9       66.9      100.0      100.0
#
#    score scaled
# 0         100.0
# 1          98.8
# 2          98.5
# 3          98.4
# 4          97.6

# %%
specify = Qs_1[Qs_1['institution'] == 'Tsinghua University']
specify1 = Qs_1[Qs_1['institution'] == 'The University of Tokyo']
specify2 = Qs_1[Qs_1['institution'] == 'Seoul National University']
specify3 = Qs_1[Qs_1['institution'] == 'KAIST - Korea Advanced Institute of Science & Technology']
specify4 = Qs_1[Qs_1['institution'] == 'Duke University']
merge2 = pd.concat([specify, specify1, specify2, specify3, specify4])
merge2
# Out:
#                                           institution  ar score  er score  \
# 13                                Tsinghua University      98.9      97.7
# 22                            The University of Tokyo     100.0      99.7
# 28                          Seoul National University      98.6      97.8
# 41  KAIST - Korea Advanced Institute of Science & ...      88.1      85.8
# 49                                    Duke University      86.1      79.8
#
#     fsr score  cpf score  ifr score  isr score  irn score  ger score  \
# 13       92.8       98.1       16.7       25.7       75.5       87.1
# 22       91.9       73.3       10.4       27.8       89.5       97.8
# 28       87.0       70.3       12.2       10.3       79.3       97.7
# 41       68.9       97.7       23.1       12.3       65.2       63.2
# 49      100.0       41.2       20.2       55.1       95.5       98.6
#
#     score scaled
# 13          90.1
# 22          85.3
# 28          82.2
# 41          79.3
# ...

# %%
specify = Qs_1[Qs_1['institution'] == 'Peking University']
specify2 = Qs_1[Qs_1['institution'] == 'Princeton University']
specify3 = Qs_1[Qs_1['institution'] == 'Columbia University']
specify4 = Qs_1[Qs_1['institution'] == "King's College London"]
specify5 = Qs_1[Qs_1['institution'] == 'The Chinese University of Hong Kong (CUHK)']
merge3 = pd.concat([specify, specify2, specify3, specify4, specify5])
merge3
# Out:
#                                    institution  ar score  er score  fsr score  \
# 11                           Peking University      99.3      96.5       87.3
# 16                        Princeton University      99.9      98.9       72.6
# 21                         Columbia University      99.7      98.1      100.0
# 36                       King's College London      88.8      83.2       74.5
# 37  The Chinese University of Hong Kong (CUHK)      87.3      49.6       60.9
#
#     cpf score  ifr score  isr score  irn score  ger score  score scaled
# 11       96.7       57.1       36.9       77.5       91.4          91.3
# 16      100.0       26.0       62.2       78.5      100.0          89.2
# 21       47.2       47.6       94.6       98.9       99.8          86.7
# 36       60.5       98.6      100.0       99.3       56.9          81.2
# 37       92.9      100.0       90.5       74.9       79.4          80.6

# %%
specify = Qs_1[Qs_1['institution'] == 'EPFL']
specify1 = Qs_1[Qs_1['institution'] == 'The Australian National University']
specify2 = Qs_1[Qs_1['institution'] == 'The University of Melbourne']
specify3 = Qs_1[Qs_1['institution'] == 'The University of Tokyo']
specify4 = Qs_1[Qs_1['institution'] == 'Tsinghua University']
merge4 = pd.concat([specify, specify1, specify2, specify3, specify4])
merge4
# Out:
#                            institution  ar score  er score  fsr score  \
# 15                                EPFL      83.7      71.8       91.1
# 29  The Australian National University      93.6      70.1       38.0
# 32         The University of Melbourne      98.6      94.9       17.9
# 22             The University of Tokyo     100.0      99.7       91.9
# 13                 Tsinghua University      98.9      97.7       92.8
#
#     cpf score  ifr score  isr score  irn score  ger score  score scaled
# 15       99.4      100.0      100.0       87.3       28.0          89.2
# 29       99.3      100.0       96.0       94.6       59.1          82.1
# 32       95.0       93.1       99.8       97.6       91.1          81.6
# 22       73.3       10.4       27.8       89.5       97.8          85.3
# 13       98.1       16.7       25.7       75.5       87.1          90.1

# %%
specify = Qs_1[Qs_1['institution'] == 'The University of Edinburgh']
specify2 = Qs_1[Qs_1['institution'] == 'Nanyang Technological University, Singapore (NTU)']
specify3 = Qs_1[Qs_1['institution'] == 'Cornell University']
specify4 = Qs_1[Qs_1['institution'] == 'Johns Hopkins University']
specify5 = Qs_1[Qs_1['institution'] == 'University of California, Berkeley (UCB)']
merge5 = pd.concat([specify, specify2, specify3, specify4, specify5])
merge5
# Out:
#                                           institution  ar score  er score  \
# 14                        The University of Edinburgh      98.0      97.2
# 18  Nanyang Technological University, Singapore (NTU)      90.4      76.1
# 19                                 Cornell University      98.3      91.4
# 23                           Johns Hopkins University      87.9      47.2
# 26           University of California, Berkeley (UCB)     100.0     100.0
#
#     fsr score  cpf score  ifr score  isr score  irn score  ger score  \
# 14       81.1       70.1       98.9       99.5       98.7       54.3
# 18       83.2       94.1      100.0       74.1       89.6       84.6
# 19       62.2       99.3       63.9       55.3       90.0       99.5
# 23      100.0       87.3       63.6       82.9       97.7       95.3
# 26       23.9       99.9       93.3       57.7       96.7       99.1
#
#     score scaled
# 14          89.5
# 18          88.4
# 19          87.2
# 23          85.1
# ...

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge1
parallel_coordinates(merge1, 'institution', color = ('r'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge2
parallel_coordinates(merge2, 'institution', color = ('g'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge3
parallel_coordinates(merge3, 'institution', color = ('b'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge4
parallel_coordinates(merge4, 'institution', color = ('orange'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge5
parallel_coordinates(merge5, 'institution', color = ('purple'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
specify = Qs_1[Qs_1['institution'] == 'Seoul National University']
specify2 = Qs_1[Qs_1['institution'] == 'KAIST - Korea Advanced Institute of Science & Technology']
merge = pd.concat([specify, specify2])
merge
# Out:
#                                           institution  ar score  er score  \
# 28                          Seoul National University      98.6      97.8
# 41  KAIST - Korea Advanced Institute of Science & ...      88.1      85.8
#
#     fsr score  cpf score  ifr score  isr score  irn score  ger score  \
# 28       87.0       70.3       12.2       10.3       79.3       97.7
# 41       68.9       97.7       23.1       12.3       65.2       63.2
#
#     score scaled
# 28          82.2
# 41          79.3

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge
parallel_coordinates(merge, 'institution', color = ('r', 'b'), alpha = 0.5)
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %%
import numpy as np
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import seaborn as sns
merge1
merge2
merge3
merge4
merge5
parallel_coordinates(merge1, 'institution', color = ('r'), alpha = 0.5)
parallel_coordinates(merge2, 'institution', color = ('g'), alpha = 0.5)
parallel_coordinates(merge3, 'institution', color = ('b'), alpha = 0.5)
parallel_coordinates(merge4, 'institution', color = ('orange'), alpha = 0.5)
parallel_coordinates(merge5, 'institution', color = ('purple'), alpha = 0.5)
plt.legend(loc = 'upper right' , bbox_to_anchor=(2.2, 1.6))
plt.figure(figsize = (7,6))
plt.rcParams["figure.figsize"] = (10,5)
plt.show()
